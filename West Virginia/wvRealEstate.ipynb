# %% [markdown]
# # Real Estate EDA - West Virginia

# %% [markdown]
# ### Imports (Pandas - Python Data Analysis Library, Numbpy - Array Proessing Package, Seaborn - Statistical Data Visualisation, Matplotlib - Static Vizualization Library)

# %%
# Standard Import Structure for EDA;
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re
import random
import time

# Importing Requests for use in API calls.
import requests


# Import Standard Packages for Date and Time;
from datetime import datetime, timedelta

# Import Beautiful Soup, Selenium, for Scraping
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# Import packages to help with parsing Information
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

# %% [markdown]
# #### Random User Agent

# %%
def GET_UA():
    uastrings = ["Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.111 Safari/537.36",\
                "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.72 Safari/537.36",\
                "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10) AppleWebKit/600.1.25 (KHTML, like Gecko) Version/8.0 Safari/600.1.25",\
                "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:33.0) Gecko/20100101 Firefox/33.0",\
                "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.111 Safari/537.36",\
                "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.111 Safari/537.36",\
                "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/600.1.17 (KHTML, like Gecko) Version/7.1 Safari/537.85.10",\
                "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko",\
                "Mozilla/5.0 (Windows NT 6.3; WOW64; rv:33.0) Gecko/20100101 Firefox/33.0",\
                "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.104 Safari/537.36"\
                ]
 
    return random.choice(uastrings)

# %% [markdown]
# ### Setup and Initialization

# %%
# Set Maximum Displayed Columns to None; All Columns Listed
pd.options.display.max_columns = None;

# Set MatPlotLib to Display Elements
# %matplotlib inline

# Import Cities in CSV file for 10 most and least expenive north carolina cities.csv
cities_df = pd.read_csv("wvCities.csv",header=0)

#Lists for Looping through GET Requests
urls = list()
cities = list()

# Create Headers for Future GET Requests
req_headers = {"User-Agent":GET_UA(),
    "Accept-Language":"en-US,en;q=0.9",
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Accept-Encoding":"gzip, deflate, br",
    "upgrade-insecure-requests":"1"}

# Print cities list to double check correct information
print(cities_df)
# Out:
#       Expensive        Affordable
# 0    Morgantown             Nitro
# 1   Martinsburg         Princeton
# 2        Elkins       Parkersburg
# 3    Huntington         Bluefield
# 4    Buckhannon          Oak Hill
# 5    Charleston       Moundsville
# 6  Charles Town        Clarksburg
# 7       Beckley  New Martinsville
# 8    Bridgeport           Grafton
# 9      Fairmont           Weirton

# %% [markdown]
# #### Create URLs For Scraping

# %%
# Checking for Sale using Zillow.com
# Using 20 Cities we use 20 URLs
# Using loop to collect information from csv to pass to beautiful soup
for i in range(10):
    for j in range(2):
        # Get City List from cities_df
        cities.append(str(cities_df.iat[i,j]))

# SUCCESSFUL CHECKING FOR INCLUSION OF ALL OF CITIES FILES REQUIRED
# Uncomment for initial check and recomment for readability afterwards
# print(cities)

# Remove White Space to Make A Correct URL by Replacing with '_'
# E.g. 'Morehead City' -> 'Morehead_City'
for i in range(0,len(cities)):
    city = str(cities[i]).replace(' ','_')
    cities[i] = city


# SUCCESSFUL CHECKING FOR CORRECT FORMAT (city with space === city_with_space) REQUIRED
# Uncomment for initial check and recomment for readability afterwards
# print(cities)


# Creating the URLS based upon created cities list
for i in range(0,len(cities)):
    urls.append('https://www.zillow.com/homes/for_sale/'+cities[i]+',-WV_rb/')

# Create Additional URLS based on further page exploration...
# Placed Last so quick excel viewing gives snapshot of individual cities and in-depth numbers are furthur down.
# ***** Can Rarely Handle 5 Pages From 20 Cities *****
# ***** Options Are Including More Cities and Less Pages, or Vice-Versa *****
for i in range(2,4):
    for j in range(0,len(cities)):
        urls.append('https://www.zillow.com/homes/for_sale/'+cities[j]+',-WV_rb/'+str(i)+'_p/')

# SUCCESSFUL CHECKING FOR APPROPRAITE URLs REQUIRED
# Uncomment for initial check and recomment for readability afterwards
print(str(len(urls)))
# Out:
# 60

# %% [markdown]
# #### Create Session and Loop Trough URLs with GET Requests

# %%
# Out:
# {'pricing': '$295,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2056', 'type': 'House', 'address': '379 Tyrone Avery Rd, Morgantown, WV 26508'}
# {'pricing': '$250,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '3120', 'type': 'House', 'address': '81 Cherry Hill Rd, Morgantown, WV 26508'}
# {'pricing': '$309,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2130', 'type': 'House', 'address': '253 Morris St, Morgantown, WV 26501'}
# {'pricing': '$194,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1148', 'type': 'House', 'address': '608 Morgan St, Morgantown, WV 26505'}
# {'pricing': '$319,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3360', 'type': 'House', 'address': '866 Beulah Rd, Morgantown, WV 26508'}
# {'pricing': '$300,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1530', 'type': 'House', 'address': '424 Arabela Ct, Morgantown, WV 26508'}
# {'pricing': '$170,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2184', 'type': 'House', 'address': '1251 Grafton Rd, Morgantown, WV 26508'}
# {'pricing': '$126,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1176', 'type': 'New construction', 'address': '18 Melvin Fields Rd, Morgantown, WV 26508'}
# {'pricing': '$219,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1405', 'type': 'House', 'address': '29 Plantation Dr, Morgantown, WV 26508'}
# {'pricing': '$295,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2056', 'type': 'House', 'address': '379 Tyrone Avery Rd, Morgantown, WV 26508'}
# {'pricing': '$250,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '3120', 'type': 'House', 'address': '81 Cherry Hill Rd, Morgantown, WV 26508'}
# {'pricing': '$309,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2130', 'type': 'House', 'address': '253 Morris St, Morgantown, WV 26501'}
# {'pricing': '$194,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1148', 'type': 'House', 'address': '608 Morgan St, Morgantown, WV 26505'}
# {'pricing': '$319,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3360', 'type': 'House', 'address': '866 Beulah Rd, Morgantown, WV 26508'}
# {'pricing': '$300,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1530', 'type': 'House', 'address': '424 Arabela Ct, Morgantown, WV 26508'}
# {'pricing': '$170,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2184', 'type': 'House', 'address': '1251 Grafton Rd, Morgantown, WV 26508'}
# {'pricing': '$126,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1176', 'type': 'New construction', 'address': '18 Melvin Fields Rd, Morgantown, WV 26508'}
# {'pricing': '$219,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1405', 'type': 'House', 'address': '29 Plantation Dr, Morgantown, WV 26508'}
# {'pricing': '$295,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2056', 'type': 'House', 'address': '379 Tyrone Avery Rd, Morgantown, WV 26508'}
# {'pricing': '$250,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '3120', 'type': 'House', 'address': '81 Cherry Hill Rd, Morgantown, WV 26508'}
# {'pricing': '$309,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2130', 'type': 'House', 'address': '253 Morris St, Morgantown, WV 26501'}
# {'pricing': '$194,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1148', 'type': 'House', 'address': '608 Morgan St, Morgantown, WV 26505'}
# {'pricing': '$319,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3360', 'type': 'House', 'address': '866 Beulah Rd, Morgantown, WV 26508'}
# {'pricing': '$300,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1530', 'type': 'House', 'address': '424 Arabela Ct, Morgantown, WV 26508'}
# {'pricing': '$170,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2184', 'type': 'House', 'address': '1251 Grafton Rd, Morgantown, WV 26508'}
# {'pricing': '$126,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1176', 'type': 'New construction', 'address': '18 Melvin Fields Rd, Morgantown, WV 26508'}
# {'pricing': '$219,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1405', 'type': 'House', 'address': '29 Plantation Dr, Morgantown, WV 26508'}
# {'pricing': '$52,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '3080', 'type': 'House', 'address': '85 31st St E, Nitro, WV 25143'}
# {'pricing': '$119,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1050', 'type': 'House', 'address': '108 Main Ave, Nitro, WV 25143'}
# {'pricing': '$194,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '2063', 'type': 'House', 'address': '13 Barrington Rd, Nitro, WV 25143'}
# {'pricing': '$239,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1928', 'type': 'House', 'address': '710 Kanawha Ave, Nitro, WV 25143'}
# {'pricing': '$115,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1511', 'type': 'House', 'address': '165 40th St, Nitro, WV 25143'}
# {'pricing': '$139,500', 'beds': '2bd', 'baths': '2ba', 'sqft': '1036', 'type': 'House', 'address': '3120 31st St, Nitro, WV 25143'}
# {'pricing': '$850,000', 'beds': '5bd', 'baths': '7ba', 'sqft': '6233', 'type': 'House', 'address': '68 Crosby Dr, Nitro, WV 25143'}
# {'pricing': '$99,999', 'beds': '3bd', 'baths': '2ba', 'sqft': '1360', 'type': 'House', 'address': '1115 1st Ave S, Nitro, WV 25143'}
# {'pricing': '$249,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1976', 'type': 'House', 'address': '110 River Ave, Nitro, WV 25143'}
# {'pricing': '$52,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '3080', 'type': 'House', 'address': '85 31st St E, Nitro, WV 25143'}
# {'pricing': '$119,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1050', 'type': 'House', 'address': '108 Main Ave, Nitro, WV 25143'}
# {'pricing': '$194,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '2063', 'type': 'House', 'address': '13 Barrington Rd, Nitro, WV 25143'}
# {'pricing': '$239,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1928', 'type': 'House', 'address': '710 Kanawha Ave, Nitro, WV 25143'}
# {'pricing': '$115,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1511', 'type': 'House', 'address': '165 40th St, Nitro, WV 25143'}
# {'pricing': '$139,500', 'beds': '2bd', 'baths': '2ba', 'sqft': '1036', 'type': 'House', 'address': '3120 31st St, Nitro, WV 25143'}
# {'pricing': '$850,000', 'beds': '5bd', 'baths': '7ba', 'sqft': '6233', 'type': 'House', 'address': '68 Crosby Dr, Nitro, WV 25143'}
# {'pricing': '$99,999', 'beds': '3bd', 'baths': '2ba', 'sqft': '1360', 'type': 'House', 'address': '1115 1st Ave S, Nitro, WV 25143'}
# {'pricing': '$249,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1976', 'type': 'House', 'address': '110 River Ave, Nitro, WV 25143'}
# {'pricing': '$52,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '3080', 'type': 'House', 'address': '85 31st St E, Nitro, WV 25143'}
# {'pricing': '$119,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1050', 'type': 'House', 'address': '108 Main Ave, Nitro, WV 25143'}
# {'pricing': '$194,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '2063', 'type': 'House', 'address': '13 Barrington Rd, Nitro, WV 25143'}
# {'pricing': '$239,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1928', 'type': 'House', 'address': '710 Kanawha Ave, Nitro, WV 25143'}
# {'pricing': '$115,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1511', 'type': 'House', 'address': '165 40th St, Nitro, WV 25143'}
# {'pricing': '$139,500', 'beds': '2bd', 'baths': '2ba', 'sqft': '1036', 'type': 'House', 'address': '3120 31st St, Nitro, WV 25143'}
# {'pricing': '$850,000', 'beds': '5bd', 'baths': '7ba', 'sqft': '6233', 'type': 'House', 'address': '68 Crosby Dr, Nitro, WV 25143'}
# {'pricing': '$99,999', 'beds': '3bd', 'baths': '2ba', 'sqft': '1360', 'type': 'House', 'address': '1115 1st Ave S, Nitro, WV 25143'}
# {'pricing': '$249,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1976', 'type': 'House', 'address': '110 River Ave, Nitro, WV 25143'}
# {'pricing': '$235,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1120', 'type': 'House', 'address': '37 Coot Ln, Martinsburg, WV 25405'}
# {'pricing': '$249,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1634', 'type': 'House', 'address': '161 Tyler Way, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '2650', 'type': 'House', 'address': '94 Toronado Dr, Martinsburg, WV 25403'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1595', 'type': 'House', 'address': '111 Clifford Dr, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '1932', 'type': 'New construction', 'address': 'LOT 53 Jensen Way, Martinsburg, WV 25401'}
# {'pricing': '$275,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1992', 'type': 'House', 'address': '137 Mercury Ct, Martinsburg, WV 25404'}
# {'pricing': '$285,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '358 Nottingham Blvd, Martinsburg, WV 25405'}
# {'pricing': '$450,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3400', 'type': 'House', 'address': '101 Catera Ct, Martinsburg, WV 25403'}
# {'pricing': '$385,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1878', 'type': 'House', 'address': '34 Renaissance Dr, Martinsburg, WV 25403'}
# {'pricing': '$235,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1120', 'type': 'House', 'address': '37 Coot Ln, Martinsburg, WV 25405'}
# {'pricing': '$249,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1634', 'type': 'House', 'address': '161 Tyler Way, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '2650', 'type': 'House', 'address': '94 Toronado Dr, Martinsburg, WV 25403'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1595', 'type': 'House', 'address': '111 Clifford Dr, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '1932', 'type': 'New construction', 'address': 'LOT 53 Jensen Way, Martinsburg, WV 25401'}
# {'pricing': '$275,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1992', 'type': 'House', 'address': '137 Mercury Ct, Martinsburg, WV 25404'}
# {'pricing': '$285,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '358 Nottingham Blvd, Martinsburg, WV 25405'}
# {'pricing': '$450,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3400', 'type': 'House', 'address': '101 Catera Ct, Martinsburg, WV 25403'}
# {'pricing': '$385,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1878', 'type': 'House', 'address': '34 Renaissance Dr, Martinsburg, WV 25403'}
# {'pricing': '$235,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1120', 'type': 'House', 'address': '37 Coot Ln, Martinsburg, WV 25405'}
# {'pricing': '$249,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1634', 'type': 'House', 'address': '161 Tyler Way, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '2650', 'type': 'House', 'address': '94 Toronado Dr, Martinsburg, WV 25403'}
# {'pricing': '$299,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1595', 'type': 'House', 'address': '111 Clifford Dr, Martinsburg, WV 25404'}
# {'pricing': '$299,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '1932', 'type': 'New construction', 'address': 'LOT 53 Jensen Way, Martinsburg, WV 25401'}
# {'pricing': '$275,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1992', 'type': 'House', 'address': '137 Mercury Ct, Martinsburg, WV 25404'}
# {'pricing': '$285,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '358 Nottingham Blvd, Martinsburg, WV 25405'}
# {'pricing': '$450,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '3400', 'type': 'House', 'address': '101 Catera Ct, Martinsburg, WV 25403'}
# {'pricing': '$385,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1878', 'type': 'House', 'address': '34 Renaissance Dr, Martinsburg, WV 25403'}
# {'pricing': '$435,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2298', 'type': 'House', 'address': '5570 Pisgah Rd, Princeton, WV 24739'}
# {'pricing': '$125,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2600', 'type': 'House', 'address': '221 College Ave, Princeton, WV 24740'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1316', 'type': 'House', 'address': '703 Garland St, Princeton, WV 24740'}
# {'pricing': '$89,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2326', 'type': 'House', 'address': '248 Hudson Ln, Princeton, WV 24739'}
# {'pricing': '$104,000', 'beds': '5bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '146 Copper St, Princeton, WV 24739'}
# {'pricing': '$249,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '657 Combs Run Rd, Princeton, WV 24739'}
# {'pricing': '$50,000', 'sqft': '0.53acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '224 Ridge Rd, Princeton, WV 24739'}
# {'pricing': '$219,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1930', 'type': 'House', 'address': '1085 Low Gap Rd, Princeton, WV 24740'}
# {'pricing': '$132,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2000', 'type': 'House', 'address': '1313 Princeton Ave, Princeton, WV 24740'}
# {'pricing': '$435,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2298', 'type': 'House', 'address': '5570 Pisgah Rd, Princeton, WV 24739'}
# {'pricing': '$125,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2600', 'type': 'House', 'address': '221 College Ave, Princeton, WV 24740'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1316', 'type': 'House', 'address': '703 Garland St, Princeton, WV 24740'}
# {'pricing': '$89,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2326', 'type': 'House', 'address': '248 Hudson Ln, Princeton, WV 24739'}
# {'pricing': '$104,000', 'beds': '5bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '146 Copper St, Princeton, WV 24739'}
# {'pricing': '$249,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '657 Combs Run Rd, Princeton, WV 24739'}
# {'pricing': '$50,000', 'sqft': '0.53acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '224 Ridge Rd, Princeton, WV 24739'}
# {'pricing': '$219,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1930', 'type': 'House', 'address': '1085 Low Gap Rd, Princeton, WV 24740'}
# {'pricing': '$132,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2000', 'type': 'House', 'address': '1313 Princeton Ave, Princeton, WV 24740'}
# {'pricing': '$435,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2298', 'type': 'House', 'address': '5570 Pisgah Rd, Princeton, WV 24739'}
# {'pricing': '$125,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2600', 'type': 'House', 'address': '221 College Ave, Princeton, WV 24740'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1316', 'type': 'House', 'address': '703 Garland St, Princeton, WV 24740'}
# {'pricing': '$89,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2326', 'type': 'House', 'address': '248 Hudson Ln, Princeton, WV 24739'}
# {'pricing': '$104,000', 'beds': '5bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '146 Copper St, Princeton, WV 24739'}
# {'pricing': '$249,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '657 Combs Run Rd, Princeton, WV 24739'}
# {'pricing': '$50,000', 'sqft': '0.53acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '224 Ridge Rd, Princeton, WV 24739'}
# {'pricing': '$219,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1930', 'type': 'House', 'address': '1085 Low Gap Rd, Princeton, WV 24740'}
# {'pricing': '$132,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2000', 'type': 'House', 'address': '1313 Princeton Ave, Princeton, WV 24740'}
# {'pricing': '$185,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1768', 'type': 'House', 'address': '2538 Gilman Rd, Elkins, WV 26241'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1368', 'type': 'House', 'address': '120 Pap Rd, Elkins, WV 26241'}
# {'pricing': '$270,000', 'beds': '3bd', 'baths': '4ba', 'sqft': '1848', 'type': 'House', 'address': '4271 Cravens Run Rd, Elkins, WV 26241'}
# {'pricing': '$649,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2325', 'type': 'New construction', 'address': '961 Tunnel Mountain Rd, Elkins, WV 26241'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1420', 'type': 'House', 'address': '21 Northview Dr, Elkins, WV 26241'}
# {'pricing': '$310,000', 'beds': '7bd', 'baths': '6ba', 'sqft': '5000', 'type': 'House', 'address': '120 2nd St, Elkins, WV 26241'}
# {'pricing': '$229,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1685', 'type': 'House', 'address': '500 Lincoln Ave, Elkins, WV 26241'}
# {'pricing': '$85,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1186', 'type': 'House', 'address': '618 Yokum St, Elkins, WV 26241'}
# {'pricing': '$138,000', 'sqft': '44.48acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Yellow House Ln, Elkins, WV 26241'}
# {'pricing': '$185,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1768', 'type': 'House', 'address': '2538 Gilman Rd, Elkins, WV 26241'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1368', 'type': 'House', 'address': '120 Pap Rd, Elkins, WV 26241'}
# {'pricing': '$270,000', 'beds': '3bd', 'baths': '4ba', 'sqft': '1848', 'type': 'House', 'address': '4271 Cravens Run Rd, Elkins, WV 26241'}
# {'pricing': '$649,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2325', 'type': 'New construction', 'address': '961 Tunnel Mountain Rd, Elkins, WV 26241'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1420', 'type': 'House', 'address': '21 Northview Dr, Elkins, WV 26241'}
# {'pricing': '$310,000', 'beds': '7bd', 'baths': '6ba', 'sqft': '5000', 'type': 'House', 'address': '120 2nd St, Elkins, WV 26241'}
# {'pricing': '$229,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1685', 'type': 'House', 'address': '500 Lincoln Ave, Elkins, WV 26241'}
# {'pricing': '$85,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1186', 'type': 'House', 'address': '618 Yokum St, Elkins, WV 26241'}
# {'pricing': '$138,000', 'sqft': '44.48acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Yellow House Ln, Elkins, WV 26241'}
# {'pricing': '$185,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1768', 'type': 'House', 'address': '2538 Gilman Rd, Elkins, WV 26241'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1368', 'type': 'House', 'address': '120 Pap Rd, Elkins, WV 26241'}
# {'pricing': '$270,000', 'beds': '3bd', 'baths': '4ba', 'sqft': '1848', 'type': 'House', 'address': '4271 Cravens Run Rd, Elkins, WV 26241'}
# {'pricing': '$649,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2325', 'type': 'New construction', 'address': '961 Tunnel Mountain Rd, Elkins, WV 26241'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1420', 'type': 'House', 'address': '21 Northview Dr, Elkins, WV 26241'}
# {'pricing': '$310,000', 'beds': '7bd', 'baths': '6ba', 'sqft': '5000', 'type': 'House', 'address': '120 2nd St, Elkins, WV 26241'}
# {'pricing': '$229,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1685', 'type': 'House', 'address': '500 Lincoln Ave, Elkins, WV 26241'}
# {'pricing': '$85,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1186', 'type': 'House', 'address': '618 Yokum St, Elkins, WV 26241'}
# {'pricing': '$138,000', 'sqft': '44.48acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Yellow House Ln, Elkins, WV 26241'}
# {'pricing': '$289,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2389', 'type': 'House', 'address': '952 Paddle Run Rd, Parkersburg, WV 26150'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1100', 'type': 'House', 'address': '1201 Rayon Dr, Parkersburg, WV 26101'}
# {'pricing': '$137,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1740', 'type': 'House', 'address': '1805 Avery St, Parkersburg, WV 26101'}
# {'pricing': '$89,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1550', 'type': 'House', 'address': '1432 30th St, Parkersburg, WV 26104'}
# {'pricing': '$384,900', 'beds': '5bd', 'baths': '5ba', 'sqft': '4951', 'type': 'House', 'address': '1361 Market St, Parkersburg, WV 26101'}
# {'pricing': '$90,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '2503 Brooklyn Ter, Parkersburg, WV 26101'}
# {'pricing': '$85,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1192', 'type': 'House', 'address': '2007 36th St, Parkersburg, WV 26104'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1026', 'type': 'House', 'address': '2610 Brooklyn Dr, Parkersburg, WV 26101'}
# {'pricing': '$85,537', 'beds': '2bd', 'baths': '1ba', 'sqft': '742', 'type': 'House', 'address': '301 Frances St, Parkersburg, WV 26101'}
# {'pricing': '$289,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2389', 'type': 'House', 'address': '952 Paddle Run Rd, Parkersburg, WV 26150'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1100', 'type': 'House', 'address': '1201 Rayon Dr, Parkersburg, WV 26101'}
# {'pricing': '$137,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1740', 'type': 'House', 'address': '1805 Avery St, Parkersburg, WV 26101'}
# {'pricing': '$89,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1550', 'type': 'House', 'address': '1432 30th St, Parkersburg, WV 26104'}
# {'pricing': '$384,900', 'beds': '5bd', 'baths': '5ba', 'sqft': '4951', 'type': 'House', 'address': '1361 Market St, Parkersburg, WV 26101'}
# {'pricing': '$90,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '2503 Brooklyn Ter, Parkersburg, WV 26101'}
# {'pricing': '$85,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1192', 'type': 'House', 'address': '2007 36th St, Parkersburg, WV 26104'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1026', 'type': 'House', 'address': '2610 Brooklyn Dr, Parkersburg, WV 26101'}
# {'pricing': '$85,537', 'beds': '2bd', 'baths': '1ba', 'sqft': '742', 'type': 'House', 'address': '301 Frances St, Parkersburg, WV 26101'}
# {'pricing': '$289,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2389', 'type': 'House', 'address': '952 Paddle Run Rd, Parkersburg, WV 26150'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1100', 'type': 'House', 'address': '1201 Rayon Dr, Parkersburg, WV 26101'}
# {'pricing': '$137,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1740', 'type': 'House', 'address': '1805 Avery St, Parkersburg, WV 26101'}
# {'pricing': '$89,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1550', 'type': 'House', 'address': '1432 30th St, Parkersburg, WV 26104'}
# {'pricing': '$384,900', 'beds': '5bd', 'baths': '5ba', 'sqft': '4951', 'type': 'House', 'address': '1361 Market St, Parkersburg, WV 26101'}
# {'pricing': '$90,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '2503 Brooklyn Ter, Parkersburg, WV 26101'}
# {'pricing': '$85,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1192', 'type': 'House', 'address': '2007 36th St, Parkersburg, WV 26104'}
# {'pricing': '$95,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1026', 'type': 'House', 'address': '2610 Brooklyn Dr, Parkersburg, WV 26101'}
# {'pricing': '$85,537', 'beds': '2bd', 'baths': '1ba', 'sqft': '742', 'type': 'House', 'address': '301 Frances St, Parkersburg, WV 26101'}
# {'pricing': '$44,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1178', 'type': 'House', 'address': '1134 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$295,000', 'beds': '6bd', 'baths': '3ba', 'sqft': '3812', 'type': 'House', 'address': '101 Richmond St, Huntington, WV 25702'}
# {'pricing': '$129,900', 'beds': '2bd', 'baths': '1ba', 'sqft': '1296', 'type': 'House', 'address': '410 Lower Ter, Huntington, WV 25705'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1372', 'type': 'House', 'address': '505 Norway Ave, Huntington, WV 25705'}
# {'pricing': '$185,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '2701', 'type': 'House', 'address': '1302 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2108', 'type': 'House', 'address': '1666 Buena Vista Dr, Huntington, WV 25704'}
# {'pricing': '$106,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '4825 Westmoreland Rd, Huntington, WV 25704'}
# {'pricing': '$93,500', 'beds': '3bd', 'baths': '1ba', 'sqft': '1677', 'type': 'House', 'address': '335 S Walnut St, Huntington, WV 25705'}
# {'pricing': '$149,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2901', 'type': 'House', 'address': '5689 Ohio River Rd, Huntington, WV 25702'}
# {'pricing': '$44,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1178', 'type': 'House', 'address': '1134 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$295,000', 'beds': '6bd', 'baths': '3ba', 'sqft': '3812', 'type': 'House', 'address': '101 Richmond St, Huntington, WV 25702'}
# {'pricing': '$129,900', 'beds': '2bd', 'baths': '1ba', 'sqft': '1296', 'type': 'House', 'address': '410 Lower Ter, Huntington, WV 25705'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1372', 'type': 'House', 'address': '505 Norway Ave, Huntington, WV 25705'}
# {'pricing': '$185,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '2701', 'type': 'House', 'address': '1302 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2108', 'type': 'House', 'address': '1666 Buena Vista Dr, Huntington, WV 25704'}
# {'pricing': '$106,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '4825 Westmoreland Rd, Huntington, WV 25704'}
# {'pricing': '$93,500', 'beds': '3bd', 'baths': '1ba', 'sqft': '1677', 'type': 'House', 'address': '335 S Walnut St, Huntington, WV 25705'}
# {'pricing': '$149,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2901', 'type': 'House', 'address': '5689 Ohio River Rd, Huntington, WV 25702'}
# {'pricing': '$44,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1178', 'type': 'House', 'address': '1134 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$295,000', 'beds': '6bd', 'baths': '3ba', 'sqft': '3812', 'type': 'House', 'address': '101 Richmond St, Huntington, WV 25702'}
# {'pricing': '$129,900', 'beds': '2bd', 'baths': '1ba', 'sqft': '1296', 'type': 'House', 'address': '410 Lower Ter, Huntington, WV 25705'}
# {'pricing': '$130,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1372', 'type': 'House', 'address': '505 Norway Ave, Huntington, WV 25705'}
# {'pricing': '$185,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '2701', 'type': 'House', 'address': '1302 Spring Valley Dr, Huntington, WV 25701'}
# {'pricing': '$199,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '2108', 'type': 'House', 'address': '1666 Buena Vista Dr, Huntington, WV 25704'}
# {'pricing': '$106,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1040', 'type': 'House', 'address': '4825 Westmoreland Rd, Huntington, WV 25704'}
# {'pricing': '$93,500', 'beds': '3bd', 'baths': '1ba', 'sqft': '1677', 'type': 'House', 'address': '335 S Walnut St, Huntington, WV 25705'}
# {'pricing': '$149,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2901', 'type': 'House', 'address': '5689 Ohio River Rd, Huntington, WV 25702'}
# {'pricing': '$310,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3898', 'type': 'House', 'address': '201 Oakdell Ave, Bluefield, WV 24701'}
# {'pricing': '$449,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '5861', 'type': 'House', 'address': '611 Mountain View Ave, Bluefield, WV 24701'}
# {'pricing': '$180,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '486', 'type': 'House', 'address': '3561 Goodwill Hollow Rd, Rock, WV 24747'}
# {'pricing': '$286,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '4053', 'type': 'House', 'address': '575 Robins Rest Rd, Bluefield, WV 24701'}
# {'pricing': '$139,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '2040', 'type': 'House', 'address': '2142 Jefferson St, Bluefield, WV 24701'}
# {'pricing': '$264,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2032', 'type': 'House', 'address': '1149 Hurricane Ridge Rd, Bluefield, WV 24701'}
# {'pricing': '$149,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1920', 'type': 'House', 'address': '2433 Fairfield Ave, Bluefield, WV 24701'}
# {'pricing': '$175,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2050', 'type': 'House', 'address': '381 Bluewell Ave, Bluefield, WV 24701'}
# {'pricing': '$59,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1456', 'type': 'House', 'address': '3507 Meadow St, Bluefield, WV 24701'}
# {'pricing': '$310,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3898', 'type': 'House', 'address': '201 Oakdell Ave, Bluefield, WV 24701'}
# {'pricing': '$449,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '5861', 'type': 'House', 'address': '611 Mountain View Ave, Bluefield, WV 24701'}
# {'pricing': '$180,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '486', 'type': 'House', 'address': '3561 Goodwill Hollow Rd, Rock, WV 24747'}
# {'pricing': '$286,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '4053', 'type': 'House', 'address': '575 Robins Rest Rd, Bluefield, WV 24701'}
# {'pricing': '$139,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '2040', 'type': 'House', 'address': '2142 Jefferson St, Bluefield, WV 24701'}
# {'pricing': '$264,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2032', 'type': 'House', 'address': '1149 Hurricane Ridge Rd, Bluefield, WV 24701'}
# {'pricing': '$149,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1920', 'type': 'House', 'address': '2433 Fairfield Ave, Bluefield, WV 24701'}
# {'pricing': '$175,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2050', 'type': 'House', 'address': '381 Bluewell Ave, Bluefield, WV 24701'}
# {'pricing': '$59,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1456', 'type': 'House', 'address': '3507 Meadow St, Bluefield, WV 24701'}
# {'pricing': '$310,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3898', 'type': 'House', 'address': '201 Oakdell Ave, Bluefield, WV 24701'}
# {'pricing': '$449,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '5861', 'type': 'House', 'address': '611 Mountain View Ave, Bluefield, WV 24701'}
# {'pricing': '$180,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '486', 'type': 'House', 'address': '3561 Goodwill Hollow Rd, Rock, WV 24747'}
# {'pricing': '$286,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '4053', 'type': 'House', 'address': '575 Robins Rest Rd, Bluefield, WV 24701'}
# {'pricing': '$139,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '2040', 'type': 'House', 'address': '2142 Jefferson St, Bluefield, WV 24701'}
# {'pricing': '$264,500', 'beds': '3bd', 'baths': '3ba', 'sqft': '2032', 'type': 'House', 'address': '1149 Hurricane Ridge Rd, Bluefield, WV 24701'}
# {'pricing': '$149,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1920', 'type': 'House', 'address': '2433 Fairfield Ave, Bluefield, WV 24701'}
# {'pricing': '$175,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2050', 'type': 'House', 'address': '381 Bluewell Ave, Bluefield, WV 24701'}
# {'pricing': '$59,900', 'beds': '3bd', 'baths': '1ba', 'sqft': '1456', 'type': 'House', 'address': '3507 Meadow St, Bluefield, WV 24701'}
# {'pricing': '$380,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2300', 'type': 'House', 'address': '613 Gatrells Rd, Buckhannon, WV 26201'}
# {'pricing': '$268,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '--', 'type': 'House', 'address': '252 Ridgeview Ln, Buckhannon, WV 26201'}
# {'pricing': '$325,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1950', 'type': 'House', 'address': '34 Skyline Dr, Buckhannon, WV 26201'}
# {'pricing': '$225K', 'beds': '3bd', 'baths': '3ba', 'sqft': '3402', 'type': 'Auction', 'address': '73 S Kanawha St, Buckhannon, WV 26201'}
# {'pricing': '$80,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2011', 'type': 'House', 'address': '10915 Old Elkins Rd, Ellamore, WV 26267'}
# {'pricing': '$250,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2048', 'type': 'House', 'address': '5585 Clarksburg Rd, Buckhannon, WV 26201'}
# {'pricing': '$255,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2461', 'type': 'House', 'address': '104 Smithfield St, Buckhannon, WV 26201'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1660', 'type': 'House', 'address': '12 Windytrail Rd, Buckhannon, WV 26201'}
# {'pricing': '$990,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2407', 'type': 'House', 'address': '377 Drummond Ln, Buckhannon, WV 26201'}
# {'pricing': '$380,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2300', 'type': 'House', 'address': '613 Gatrells Rd, Buckhannon, WV 26201'}
# {'pricing': '$268,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '--', 'type': 'House', 'address': '252 Ridgeview Ln, Buckhannon, WV 26201'}
# {'pricing': '$325,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1950', 'type': 'House', 'address': '34 Skyline Dr, Buckhannon, WV 26201'}
# {'pricing': '$225K', 'beds': '3bd', 'baths': '3ba', 'sqft': '3402', 'type': 'Auction', 'address': '73 S Kanawha St, Buckhannon, WV 26201'}
# {'pricing': '$80,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2011', 'type': 'House', 'address': '10915 Old Elkins Rd, Ellamore, WV 26267'}
# {'pricing': '$250,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2048', 'type': 'House', 'address': '5585 Clarksburg Rd, Buckhannon, WV 26201'}
# {'pricing': '$255,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2461', 'type': 'House', 'address': '104 Smithfield St, Buckhannon, WV 26201'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1660', 'type': 'House', 'address': '12 Windytrail Rd, Buckhannon, WV 26201'}
# {'pricing': '$990,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2407', 'type': 'House', 'address': '377 Drummond Ln, Buckhannon, WV 26201'}
# {'pricing': '$380,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2300', 'type': 'House', 'address': '613 Gatrells Rd, Buckhannon, WV 26201'}
# {'pricing': '$268,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '--', 'type': 'House', 'address': '252 Ridgeview Ln, Buckhannon, WV 26201'}
# {'pricing': '$325,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '1950', 'type': 'House', 'address': '34 Skyline Dr, Buckhannon, WV 26201'}
# {'pricing': '$225K', 'beds': '3bd', 'baths': '3ba', 'sqft': '3402', 'type': 'Auction', 'address': '73 S Kanawha St, Buckhannon, WV 26201'}
# {'pricing': '$80,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2011', 'type': 'House', 'address': '10915 Old Elkins Rd, Ellamore, WV 26267'}
# {'pricing': '$250,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2048', 'type': 'House', 'address': '5585 Clarksburg Rd, Buckhannon, WV 26201'}
# {'pricing': '$255,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2461', 'type': 'House', 'address': '104 Smithfield St, Buckhannon, WV 26201'}
# {'pricing': '$139,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1660', 'type': 'House', 'address': '12 Windytrail Rd, Buckhannon, WV 26201'}
# {'pricing': '$990,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2407', 'type': 'House', 'address': '377 Drummond Ln, Buckhannon, WV 26201'}
# {'pricing': '$35,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1152', 'type': 'House', 'address': '547 Campbells Creek Dr, Charleston, WV 25306'}
# {'pricing': '$285,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '4054', 'type': 'House', 'address': '3 Guy Ln, Charleston, WV 25313'}
# {'pricing': '$209,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2573', 'type': 'House', 'address': '1226 Oakmont Rd, Charleston, WV 25314'}
# {'pricing': '$799,999', 'beds': '5bd', 'baths': '6ba', 'sqft': '4822', 'type': 'House', 'address': '1600 Stonehenge Rd, Charleston, WV 25314'}
# {'pricing': '$194,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '2262', 'type': 'House', 'address': '5346 Frontier Dr, Cross Lanes, WV 25313'}
# {'pricing': '$110,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1250', 'type': 'House', 'address': '5012 Kilgore Ln, Cross Lanes, WV 25313'}
# {'pricing': '$189,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1815', 'type': 'House', 'address': '1407 Viewmont Dr, Charleston, WV 25302'}
# {'pricing': '$129,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1744', 'type': 'House', 'address': '704 Hall St, Charleston, WV 25302'}
# {'pricing': '$345,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '225 Cheyenne Ln, Charleston, WV 25312'}
# {'pricing': '$35,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1152', 'type': 'House', 'address': '547 Campbells Creek Dr, Charleston, WV 25306'}
# {'pricing': '$285,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '4054', 'type': 'House', 'address': '3 Guy Ln, Charleston, WV 25313'}
# {'pricing': '$209,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2573', 'type': 'House', 'address': '1226 Oakmont Rd, Charleston, WV 25314'}
# {'pricing': '$799,999', 'beds': '5bd', 'baths': '6ba', 'sqft': '4822', 'type': 'House', 'address': '1600 Stonehenge Rd, Charleston, WV 25314'}
# {'pricing': '$194,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '2262', 'type': 'House', 'address': '5346 Frontier Dr, Cross Lanes, WV 25313'}
# {'pricing': '$110,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1250', 'type': 'House', 'address': '5012 Kilgore Ln, Cross Lanes, WV 25313'}
# {'pricing': '$189,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1815', 'type': 'House', 'address': '1407 Viewmont Dr, Charleston, WV 25302'}
# {'pricing': '$129,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1744', 'type': 'House', 'address': '704 Hall St, Charleston, WV 25302'}
# {'pricing': '$345,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '225 Cheyenne Ln, Charleston, WV 25312'}
# {'pricing': '$35,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1152', 'type': 'House', 'address': '547 Campbells Creek Dr, Charleston, WV 25306'}
# {'pricing': '$285,000', 'beds': '5bd', 'baths': '4ba', 'sqft': '4054', 'type': 'House', 'address': '3 Guy Ln, Charleston, WV 25313'}
# {'pricing': '$209,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2573', 'type': 'House', 'address': '1226 Oakmont Rd, Charleston, WV 25314'}
# {'pricing': '$799,999', 'beds': '5bd', 'baths': '6ba', 'sqft': '4822', 'type': 'House', 'address': '1600 Stonehenge Rd, Charleston, WV 25314'}
# {'pricing': '$194,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '2262', 'type': 'House', 'address': '5346 Frontier Dr, Cross Lanes, WV 25313'}
# {'pricing': '$110,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1250', 'type': 'House', 'address': '5012 Kilgore Ln, Cross Lanes, WV 25313'}
# {'pricing': '$189,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1815', 'type': 'House', 'address': '1407 Viewmont Dr, Charleston, WV 25302'}
# {'pricing': '$129,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1744', 'type': 'House', 'address': '704 Hall St, Charleston, WV 25302'}
# {'pricing': '$345,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'House', 'address': '225 Cheyenne Ln, Charleston, WV 25312'}
# {'pricing': '$75,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1638', 'type': 'House', 'address': '1101 5th Street, Moundsville, WV 26041'}
# {'pricing': '$160,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '2921 Fork Ridge Road, Moundsville, WV 26041'}
# {'pricing': '$617,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '3750', 'type': 'House', 'address': '70 Hidden View Drive, Moundsville, WV 26041'}
# {'pricing': '$55,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1500', 'type': 'House', 'address': '210 Washington Avenue, Moundsville, WV 26041'}
# {'pricing': '$180,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2286', 'type': 'House', 'address': '1103 5th Street, Moundsville, WV 26041'}
# {'pricing': '$120,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '1404 Center Street, Moundsville, WV 26041'}
# {'pricing': '$70,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1040', 'type': 'House', 'address': '4301 Taylors Ridge Rd, Proctor, WV 26055'}
# {'pricing': '$92,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1478', 'type': 'House', 'address': '1200 9TH STREET, Moundsville, WV 26041'}
# {'pricing': '$140,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '960', 'type': 'House', 'address': '98 Scenic Hills Drive, Moundsville, WV 26041'}
# {'pricing': '$75,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1638', 'type': 'House', 'address': '1101 5th Street, Moundsville, WV 26041'}
# {'pricing': '$160,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '2921 Fork Ridge Road, Moundsville, WV 26041'}
# {'pricing': '$617,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '3750', 'type': 'House', 'address': '70 Hidden View Drive, Moundsville, WV 26041'}
# {'pricing': '$55,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1500', 'type': 'House', 'address': '210 Washington Avenue, Moundsville, WV 26041'}
# {'pricing': '$180,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2286', 'type': 'House', 'address': '1103 5th Street, Moundsville, WV 26041'}
# {'pricing': '$120,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '1404 Center Street, Moundsville, WV 26041'}
# {'pricing': '$70,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1040', 'type': 'House', 'address': '4301 Taylors Ridge Rd, Proctor, WV 26055'}
# {'pricing': '$92,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1478', 'type': 'House', 'address': '1200 9TH STREET, Moundsville, WV 26041'}
# {'pricing': '$140,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '960', 'type': 'House', 'address': '98 Scenic Hills Drive, Moundsville, WV 26041'}
# {'pricing': '$75,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1638', 'type': 'House', 'address': '1101 5th Street, Moundsville, WV 26041'}
# {'pricing': '$160,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '2921 Fork Ridge Road, Moundsville, WV 26041'}
# {'pricing': '$617,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '3750', 'type': 'House', 'address': '70 Hidden View Drive, Moundsville, WV 26041'}
# {'pricing': '$55,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1500', 'type': 'House', 'address': '210 Washington Avenue, Moundsville, WV 26041'}
# {'pricing': '$180,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2286', 'type': 'House', 'address': '1103 5th Street, Moundsville, WV 26041'}
# {'pricing': '$120,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1356', 'type': 'House', 'address': '1404 Center Street, Moundsville, WV 26041'}
# {'pricing': '$70,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1040', 'type': 'House', 'address': '4301 Taylors Ridge Rd, Proctor, WV 26055'}
# {'pricing': '$92,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1478', 'type': 'House', 'address': '1200 9TH STREET, Moundsville, WV 26041'}
# {'pricing': '$140,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '960', 'type': 'House', 'address': '98 Scenic Hills Drive, Moundsville, WV 26041'}
# {'pricing': '$189,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '2280', 'type': 'House', 'address': '109 Deegans St, Beckley, WV 25801'}
# {'pricing': '$69,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1228', 'type': 'House', 'address': '115 Pine St, Beckley, WV 25801'}
# {'pricing': '$99,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '219 Church St, Beckley, WV 25801'}
# {'pricing': '$117,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1546', 'type': 'Foreclosure', 'address': '251 McBerry St, Beckley, WV 25801'}
# {'pricing': '$134,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2224', 'type': 'House', 'address': '307 Wyoming Ave, Beckley, WV 25801'}
# {'pricing': '$164,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1762', 'type': 'House', 'address': '211 Berkley St, Beckley, WV 25801'}
# {'pricing': '$479,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '4065', 'type': 'House', 'address': '37 Chestnut Dr, Beckley, WV 25801'}
# {'pricing': '$45,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1480', 'type': 'House', 'address': '3920 Harper Rd, Beckley, WV 25801'}
# {'pricing': '$124,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '203 Summers St, Beckley, WV 25801'}
# {'pricing': '$189,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '2280', 'type': 'House', 'address': '109 Deegans St, Beckley, WV 25801'}
# {'pricing': '$69,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1228', 'type': 'House', 'address': '115 Pine St, Beckley, WV 25801'}
# {'pricing': '$99,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '219 Church St, Beckley, WV 25801'}
# {'pricing': '$117,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1546', 'type': 'Foreclosure', 'address': '251 McBerry St, Beckley, WV 25801'}
# {'pricing': '$134,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2224', 'type': 'House', 'address': '307 Wyoming Ave, Beckley, WV 25801'}
# {'pricing': '$164,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1762', 'type': 'House', 'address': '211 Berkley St, Beckley, WV 25801'}
# {'pricing': '$479,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '4065', 'type': 'House', 'address': '37 Chestnut Dr, Beckley, WV 25801'}
# {'pricing': '$45,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1480', 'type': 'House', 'address': '3920 Harper Rd, Beckley, WV 25801'}
# {'pricing': '$124,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '203 Summers St, Beckley, WV 25801'}
# {'pricing': '$189,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '2280', 'type': 'House', 'address': '109 Deegans St, Beckley, WV 25801'}
# {'pricing': '$69,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1228', 'type': 'House', 'address': '115 Pine St, Beckley, WV 25801'}
# {'pricing': '$99,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '219 Church St, Beckley, WV 25801'}
# {'pricing': '$117,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1546', 'type': 'Foreclosure', 'address': '251 McBerry St, Beckley, WV 25801'}
# {'pricing': '$134,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '2224', 'type': 'House', 'address': '307 Wyoming Ave, Beckley, WV 25801'}
# {'pricing': '$164,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1762', 'type': 'House', 'address': '211 Berkley St, Beckley, WV 25801'}
# {'pricing': '$479,900', 'beds': '4bd', 'baths': '3ba', 'sqft': '4065', 'type': 'House', 'address': '37 Chestnut Dr, Beckley, WV 25801'}
# {'pricing': '$45,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '1480', 'type': 'House', 'address': '3920 Harper Rd, Beckley, WV 25801'}
# {'pricing': '$124,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '203 Summers St, Beckley, WV 25801'}
# {'pricing': '$289,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2502', 'type': 'House', 'address': '31 Neubauer Dr, New Martinsville, WV 26155'}
# {'pricing': '$164,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1904', 'type': 'House', 'address': '428 BEECH STREET, New Martinsville, WV 26155'}
# {'pricing': '$349,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '4140', 'type': 'House', 'address': '760 4th Street, New Martinsville, WV 26155'}
# {'pricing': '$232,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1683', 'type': 'House', 'address': '406 Edgewood Terrace, New Martinsville, WV 26155'}
# {'pricing': '$139,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '1954', 'type': 'House', 'address': '***616 4th St, New Martinsville, WV 26155'}
# {'pricing': '$129,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1785', 'type': 'House', 'address': '170 Dunlap, New Martinsville, WV 26155'}
# {'pricing': '$65,000', 'sqft': '3.06acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '5122 Mountaineer Highway, New Martinsville, WV 26155'}
# {'pricing': '$259,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2422', 'type': 'House', 'address': '783 Fifth Street, New Martinsville, WV 25155'}
# {'pricing': '$45,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1378', 'type': 'House', 'address': '144 Wayt, New Martinsville, WV 26155'}
# {'pricing': '$289,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2502', 'type': 'House', 'address': '31 Neubauer Dr, New Martinsville, WV 26155'}
# {'pricing': '$164,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1904', 'type': 'House', 'address': '428 BEECH STREET, New Martinsville, WV 26155'}
# {'pricing': '$349,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '4140', 'type': 'House', 'address': '760 4th Street, New Martinsville, WV 26155'}
# {'pricing': '$232,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '1683', 'type': 'House', 'address': '406 Edgewood Terrace, New Martinsville, WV 26155'}
# {'pricing': '$139,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '1954', 'type': 'House', 'address': '***616 4th St, New Martinsville, WV 26155'}
# {'pricing': '$129,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1785', 'type': 'House', 'address': '170 Dunlap, New Martinsville, WV 26155'}
# {'pricing': '$65,000', 'sqft': '3.06acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '5122 Mountaineer Highway, New Martinsville, WV 26155'}
# {'pricing': '$259,000', 'beds': '4bd', 'baths': '2ba', 'sqft': '2422', 'type': 'House', 'address': '783 Fifth Street, New Martinsville, WV 25155'}
# {'pricing': '$45,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1378', 'type': 'House', 'address': '144 Wayt, New Martinsville, WV 26155'}
# {'pricing': '$289,000', 'beds': '4bd', 'baths': '3ba', 'sqft': '2502', 'type': 'House', 'address': '31 Neubauer Dr, New Martinsville, WV 26155'}
# ...
# {'pricing': '$155,000', 'sqft': '1.02acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 8 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$449,000', 'sqft': '8.74acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 5 Arcadia Ln, Bridgeport, WV 26330'}
# {'pricing': '$150,000', 'sqft': '1acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 7 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$80,000', 'sqft': '0.62acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Lots 25 26 & Point St #24 & 27, Bridgeport, WV 26330'}
# {'pricing': '$34,000', 'sqft': '1.05acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Phase I Evergreen Dr LOT 15, Bridgeport, WV 26330'}
# {'pricing': '$70,000', 'sqft': '1.07acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Diamond Cv, Bridgeport, WV 26330'}
# {'pricing': '$155,000', 'sqft': '1.03acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 13 Trailhead Way, Bridgeport, WV 26330'}
# {'pricing': '$93,500', 'sqft': '1.59acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '17 Diamond Cv, Bridgeport, WV 26330'}
# {'pricing': '$289,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1795', 'type': 'New construction', 'address': '0 Dover Ct, Bridgeport, WV 26330'}
# {'pricing': '$155,000', 'sqft': '1.02acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 8 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$449,000', 'sqft': '8.74acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 5 Arcadia Ln, Bridgeport, WV 26330'}
# {'pricing': '$150,000', 'sqft': '1acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 7 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$80,000', 'sqft': '0.62acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Lots 25 26 & Point St #24 & 27, Bridgeport, WV 26330'}
# {'pricing': '$34,000', 'sqft': '1.05acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Phase I Evergreen Dr LOT 15, Bridgeport, WV 26330'}
# {'pricing': '$70,000', 'sqft': '1.07acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Diamond Cv, Bridgeport, WV 26330'}
# {'pricing': '$155,000', 'sqft': '1.03acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 13 Trailhead Way, Bridgeport, WV 26330'}
# {'pricing': '$93,500', 'sqft': '1.59acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': '17 Diamond Cv, Bridgeport, WV 26330'}
# {'pricing': '$289,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1795', 'type': 'New construction', 'address': '0 Dover Ct, Bridgeport, WV 26330'}
# {'pricing': '$155,000', 'sqft': '1.02acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 8 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$449,000', 'sqft': '8.74acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 5 Arcadia Ln, Bridgeport, WV 26330'}
# {'pricing': '$150,000', 'sqft': '1acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'LOT 7 Vale Dr, Bridgeport, WV 26330'}
# {'pricing': '$80,000', 'sqft': '0.62acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Lots 25 26 & Point St #24 & 27, Bridgeport, WV 26330'}
# {'pricing': '$34,000', 'sqft': '1.05acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Phase I Evergreen Dr LOT 15, Bridgeport, WV 26330'}
# {'pricing': '$70,000', 'sqft': '1.07acreslot', 'beds': 0, 'baths': 0, 'type': 'Land', 'address': 'Diamond Cv, Bridgeport, WV 26330'}
# {'pricing': '$49,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1411', 'type': 'House', 'address': '145 Country Club Rd, Grafton, WV 26354'}
# {'pricing': '$75,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2040', 'type': 'Multi-family home', 'address': '240 Maple Ave, Grafton, WV 26354'}
# {'pricing': '$99,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1075', 'type': 'House', 'address': '5 Leonard St, Grafton, WV 26354'}
# {'pricing': '$199,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1098', 'type': 'House', 'address': '78 Tom Taylor Dr, Grafton, WV 26354'}
# {'pricing': '$349,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '4705', 'type': 'House', 'address': '353 Pruntytown Pike, Grafton, WV 26354'}
# {'pricing': '$179,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '692 Barcus Rd, Grafton, WV 26354'}
# {'pricing': '$112,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1822', 'type': 'House', 'address': '137 Walnut Ln, Thornton, WV 26440'}
# {'pricing': '$274,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1647', 'type': 'House', 'address': '42 Meadow Ln, Grafton, WV 26354'}
# {'pricing': '$299,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2100', 'type': 'House', 'address': '151 Shackleford Ln, Grafton, WV 26354'}
# {'pricing': '$49,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1411', 'type': 'House', 'address': '145 Country Club Rd, Grafton, WV 26354'}
# {'pricing': '$75,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2040', 'type': 'Multi-family home', 'address': '240 Maple Ave, Grafton, WV 26354'}
# {'pricing': '$99,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1075', 'type': 'House', 'address': '5 Leonard St, Grafton, WV 26354'}
# {'pricing': '$199,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1098', 'type': 'House', 'address': '78 Tom Taylor Dr, Grafton, WV 26354'}
# {'pricing': '$349,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '4705', 'type': 'House', 'address': '353 Pruntytown Pike, Grafton, WV 26354'}
# {'pricing': '$179,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '692 Barcus Rd, Grafton, WV 26354'}
# {'pricing': '$112,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1822', 'type': 'House', 'address': '137 Walnut Ln, Thornton, WV 26440'}
# {'pricing': '$274,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1647', 'type': 'House', 'address': '42 Meadow Ln, Grafton, WV 26354'}
# {'pricing': '$299,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2100', 'type': 'House', 'address': '151 Shackleford Ln, Grafton, WV 26354'}
# {'pricing': '$49,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1411', 'type': 'House', 'address': '145 Country Club Rd, Grafton, WV 26354'}
# {'pricing': '$75,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2040', 'type': 'Multi-family home', 'address': '240 Maple Ave, Grafton, WV 26354'}
# {'pricing': '$99,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1075', 'type': 'House', 'address': '5 Leonard St, Grafton, WV 26354'}
# {'pricing': '$199,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1098', 'type': 'House', 'address': '78 Tom Taylor Dr, Grafton, WV 26354'}
# {'pricing': '$349,000', 'beds': '5bd', 'baths': '5ba', 'sqft': '4705', 'type': 'House', 'address': '353 Pruntytown Pike, Grafton, WV 26354'}
# {'pricing': '$179,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1344', 'type': 'House', 'address': '692 Barcus Rd, Grafton, WV 26354'}
# {'pricing': '$112,500', 'beds': '3bd', 'baths': '2ba', 'sqft': '1822', 'type': 'House', 'address': '137 Walnut Ln, Thornton, WV 26440'}
# {'pricing': '$274,900', 'beds': '3bd', 'baths': '3ba', 'sqft': '1647', 'type': 'House', 'address': '42 Meadow Ln, Grafton, WV 26354'}
# {'pricing': '$299,000', 'beds': '3bd', 'baths': '3ba', 'sqft': '2100', 'type': 'House', 'address': '151 Shackleford Ln, Grafton, WV 26354'}
# {'pricing': '$72,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '768', 'type': 'House', 'address': '714 Virginia Ave, Fairmont, WV 26554'}
# {'pricing': '$99,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2186', 'type': 'Multi-family home', 'address': '530 Walnut Ave, Fairmont, WV 26554'}
# {'pricing': '$410,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3168', 'type': 'Multi-family home', 'address': '28-30 Haven Ln #32, Fairmont, WV 26554'}
# {'pricing': '$338,999+', 'beds': '3bd', 'baths': '2ba', 'sqft': '1687', 'type': 'New construction', 'address': 'Edgewood II Plan, Eastview Manor'}
# {'pricing': '$59,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1100', 'type': 'House', 'address': '1103 Lowell St, Fairmont, WV 26554'}
# {'pricing': '$49,900', 'beds': '--bd', 'baths': '--ba', 'sqft': '2038', 'type': 'Multi-family home', 'address': '510 Pennsylvania Ave, Fairmont, WV 26554'}
# {'pricing': '$105,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1002', 'type': 'House', 'address': '341 Satterfield St, Fairmont, WV 26554'}
# {'pricing': '$60,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '715', 'type': 'House', 'address': '1014 Fay St, Fairmont, WV 26554'}
# {'pricing': '$341,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2216', 'type': 'New construction', 'address': '0 Eastview Way, Fairmont, WV 26554'}
# {'pricing': '$72,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '768', 'type': 'House', 'address': '714 Virginia Ave, Fairmont, WV 26554'}
# {'pricing': '$99,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2186', 'type': 'Multi-family home', 'address': '530 Walnut Ave, Fairmont, WV 26554'}
# {'pricing': '$410,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3168', 'type': 'Multi-family home', 'address': '28-30 Haven Ln #32, Fairmont, WV 26554'}
# {'pricing': '$338,999+', 'beds': '3bd', 'baths': '2ba', 'sqft': '1687', 'type': 'New construction', 'address': 'Edgewood II Plan, Eastview Manor'}
# {'pricing': '$59,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1100', 'type': 'House', 'address': '1103 Lowell St, Fairmont, WV 26554'}
# {'pricing': '$49,900', 'beds': '--bd', 'baths': '--ba', 'sqft': '2038', 'type': 'Multi-family home', 'address': '510 Pennsylvania Ave, Fairmont, WV 26554'}
# {'pricing': '$105,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1002', 'type': 'House', 'address': '341 Satterfield St, Fairmont, WV 26554'}
# {'pricing': '$60,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '715', 'type': 'House', 'address': '1014 Fay St, Fairmont, WV 26554'}
# {'pricing': '$341,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2216', 'type': 'New construction', 'address': '0 Eastview Way, Fairmont, WV 26554'}
# {'pricing': '$72,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '768', 'type': 'House', 'address': '714 Virginia Ave, Fairmont, WV 26554'}
# {'pricing': '$99,000', 'beds': '5bd', 'baths': '3ba', 'sqft': '2186', 'type': 'Multi-family home', 'address': '530 Walnut Ave, Fairmont, WV 26554'}
# {'pricing': '$410,000', 'beds': '4bd', 'baths': '4ba', 'sqft': '3168', 'type': 'Multi-family home', 'address': '28-30 Haven Ln #32, Fairmont, WV 26554'}
# {'pricing': '$338,999+', 'beds': '3bd', 'baths': '2ba', 'sqft': '1687', 'type': 'New construction', 'address': 'Edgewood II Plan, Eastview Manor'}
# {'pricing': '$59,900', 'beds': '2bd', 'baths': '2ba', 'sqft': '1100', 'type': 'House', 'address': '1103 Lowell St, Fairmont, WV 26554'}
# {'pricing': '$49,900', 'beds': '--bd', 'baths': '--ba', 'sqft': '2038', 'type': 'Multi-family home', 'address': '510 Pennsylvania Ave, Fairmont, WV 26554'}
# {'pricing': '$105,000', 'beds': '2bd', 'baths': '1ba', 'sqft': '1002', 'type': 'House', 'address': '341 Satterfield St, Fairmont, WV 26554'}
# {'pricing': '$60,000', 'beds': '2bd', 'baths': '2ba', 'sqft': '715', 'type': 'House', 'address': '1014 Fay St, Fairmont, WV 26554'}
# {'pricing': '$341,999', 'beds': '4bd', 'baths': '3ba', 'sqft': '2216', 'type': 'New construction', 'address': '0 Eastview Way, Fairmont, WV 26554'}
# {'pricing': '$179,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '3068', 'type': 'House', 'address': '2907 Wylie Ridge Rd, Weirton, WV 26062'}
# {'pricing': '$165,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '2027', 'type': 'House', 'address': '3421 Pennsylvania Ave, Weirton, WV 26062'}
# {'pricing': '$124,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1447', 'type': 'House', 'address': '1496 Cove Rd, Weirton, WV 26062'}
# {'pricing': '$49,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1872', 'type': 'Multi-family home', 'address': '108 Paul Ave, Weirton, WV 26062'}
# {'pricing': '$139,969', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'Home', 'address': '95 Swearingen Rd, Weirton, WV 26062'}
# {'pricing': '$37,500', 'beds': '2bd', 'baths': '1ba', 'sqft': '982', 'type': 'House', 'address': '223 Franklin St, Weirton, WV 26062'}
# {'pricing': '$149,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '210 Mahan Rd, Weirton, WV 26062'}
# {'pricing': '$189,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1608', 'type': 'House', 'address': '1325 Overlook Dr, Weirton, WV 26062'}
# {'pricing': '$18,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '108 N 12th St, Weirton, WV 26062'}
# {'pricing': '$179,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '3068', 'type': 'House', 'address': '2907 Wylie Ridge Rd, Weirton, WV 26062'}
# {'pricing': '$165,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '2027', 'type': 'House', 'address': '3421 Pennsylvania Ave, Weirton, WV 26062'}
# {'pricing': '$124,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1447', 'type': 'House', 'address': '1496 Cove Rd, Weirton, WV 26062'}
# {'pricing': '$49,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1872', 'type': 'Multi-family home', 'address': '108 Paul Ave, Weirton, WV 26062'}
# {'pricing': '$139,969', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'Home', 'address': '95 Swearingen Rd, Weirton, WV 26062'}
# {'pricing': '$37,500', 'beds': '2bd', 'baths': '1ba', 'sqft': '982', 'type': 'House', 'address': '223 Franklin St, Weirton, WV 26062'}
# {'pricing': '$149,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '210 Mahan Rd, Weirton, WV 26062'}
# {'pricing': '$189,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1608', 'type': 'House', 'address': '1325 Overlook Dr, Weirton, WV 26062'}
# {'pricing': '$18,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '108 N 12th St, Weirton, WV 26062'}
# {'pricing': '$179,900', 'beds': '5bd', 'baths': '2ba', 'sqft': '3068', 'type': 'House', 'address': '2907 Wylie Ridge Rd, Weirton, WV 26062'}
# {'pricing': '$165,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '2027', 'type': 'House', 'address': '3421 Pennsylvania Ave, Weirton, WV 26062'}
# {'pricing': '$124,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1447', 'type': 'House', 'address': '1496 Cove Rd, Weirton, WV 26062'}
# {'pricing': '$49,900', 'beds': '4bd', 'baths': '2ba', 'sqft': '1872', 'type': 'Multi-family home', 'address': '108 Paul Ave, Weirton, WV 26062'}
# {'pricing': '$139,969', 'beds': '3bd', 'baths': '2ba', 'sqft': '1820', 'type': 'Home', 'address': '95 Swearingen Rd, Weirton, WV 26062'}
# {'pricing': '$37,500', 'beds': '2bd', 'baths': '1ba', 'sqft': '982', 'type': 'House', 'address': '223 Franklin St, Weirton, WV 26062'}
# {'pricing': '$149,900', 'beds': '3bd', 'baths': '2ba', 'sqft': '1568', 'type': 'House', 'address': '210 Mahan Rd, Weirton, WV 26062'}
# {'pricing': '$189,000', 'beds': '3bd', 'baths': '2ba', 'sqft': '1608', 'type': 'House', 'address': '1325 Overlook Dr, Weirton, WV 26062'}
# {'pricing': '$18,000', 'beds': '3bd', 'baths': '1ba', 'sqft': '1200', 'type': 'House', 'address': '108 N 12th St, Weirton, WV 26062'}
# Amount of listings Scraped: 1365
#          Price Beds Baths Square_Feet   Type  \
# 0     $295,000  3bd   2ba        2056  House
# 1     $250,000  3bd   3ba        3120  House
# 2     $309,000  4bd   3ba        2130  House
# 3     $194,000  3bd   2ba        1148  House
# 4     $319,000  5bd   4ba        3360  House
# ...        ...  ...   ...         ...    ...
# 1360  $139,969  3bd   2ba        1820   Home
# 1361   $37,500  2bd   1ba         982  House
# 1362  $149,900  3bd   2ba        1568  House
# 1363  $189,000  3bd   2ba        1608  House
# 1364   $18,000  3bd   1ba        1200  House
#
#                                         Address
# 0     379 Tyrone Avery Rd, Morgantown, WV 26508
# 1       81 Cherry Hill Rd, Morgantown, WV 26508
# 2           253 Morris St, Morgantown, WV 26501
# 3           608 Morgan St, Morgantown, WV 26505
# 4           866 Beulah Rd, Morgantown, WV 26508
# ...                                         ...
# 1360        95 Swearingen Rd, Weirton, WV 26062
# 1361         223 Franklin St, Weirton, WV 26062
# 1362            210 Mahan Rd, Weirton, WV 26062
# 1363        1325 Overlook Dr, Weirton, WV 26062
# 1364           108 N 12th St, Weirton, WV 26062
#
# [1365 rows x 6 columns]

# %%
# Object for Individual Listings to be placed into List
# List to Store Total Scraped Information
l=[]
obj = {}

# Create a DataFrame for Storage with Columns listing Wanted Information
house_df = pd.DataFrame(columns=['Price','Beds','Baths','Square_Feet','Type','Address'])

#loop through sessions to get urls used be Reqeusts Package for pulling information

with requests.Session() as s:

    for i in range(0,len(urls)):
        r = s.get(urls[i], headers=req_headers)
    
        # Parse bs4 response into html parser
        soup = BeautifulSoup(r.text, 'html.parser')
        
        # Loop through the created soup to add to df
        for i in soup:
            properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})

            for x in range(0,len(properties)):
                
                # Try and get pricing from listing excluding those without a number
                try:
                    obj["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
                except:
                    obj["pricing"]='Unknown'

                # Try to get Information Sizing
                # i.e. Beds, Baths, Square Feet, and Type (House, Apartment, Single-Family or Multi-Family Home)

                try:
                    sizeInfo=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

                    # ***** Check for Studios ***** ***** Remove Them ******
                    if 'studio' in sizeInfo:

                        sizeInfo = 'Unknown Unknown Unknown Unknown'

                        split = sizeInfo.split(' ',3)

                        obj['beds'] = split[0]
                        obj['baths'] = split[1]
                        obj['sqft'] = split[2]
                        obj['type'] = split[3]
                    else:
                        # Format Correctly The Sizing Information for Split

                        # Steps:
                        # Remove Sq Ft Unit
                        # Remove Additional Info Indicator '-'
                        # Remove 'For Sale' Descriptor
                        # Remove WhiteSpace
                        # Correctly Gap Beds and Baths (Bd, and Ba) to be Uniform
                        # Remove Commas for Easier Delimitor for Later Split
                        sizeInfo = sizeInfo.replace('sqft','',1)
                        sizeInfo = sizeInfo.replace(' - ','')
                        sizeInfo = sizeInfo.replace(' for sale',"")

                        sizeInfo = sizeInfo.replace(" ","",2)

                        sizeInfo = sizeInfo.replace('bds','bd')
                        sizeInfo = sizeInfo.replace('bd','bd ')
                        sizeInfo = sizeInfo.replace('ba','ba ')
                        sizeInfo = sizeInfo.replace(',','')

                        # Create split based on whitespace and only 3 split times for grouping construction details
                        split = sizeInfo.split(' ',3)
                        
                        # Place information into object for later use
                        # Edit Some Info --- If Land It is Ending up in 'Beds', and Type is Ending up in Baths

                        if split[0].count('acre') or split[0].count('lot'):
                            obj['sqft'] = split[0]
                            obj['beds'] = 0
                            obj['baths'] = 0
                            obj['type'] = split[3]
                        else:
                            obj['beds'] = split[0]
                            obj['baths'] = split[1]
                            obj['sqft'] = split[2]
                            obj['type'] = split[3]
                        
                except:
                    obj['sqft'] = 'Unknown'
                    obj['beds'] = 'Unknown'
                    obj['baths'] = 'Unknown'
                    obj['type'] = 'Unknown'

                # Find Address information and exclude those without written address
                try:
                    obj["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
                except:
                    obj["address"]='Unknown'
                
                print(obj)
                l.append(obj)  
                obj={}
                time.sleep(random.randint(5,20))


# Setup Cost to be added to data frame using list
cost = []
# Setup Beds to be added to data frame using list
beds = []
# Setup Baths to be added to data frame using list
baths = []
# Setup Square Feet to be added to data frame using list
sqft = []
# Setup Types to be added to data frame using list
types = []
# Setup Address to be added to data frame using list
address = []


# If you really want to check for log output

# For Whole Log
# print(l)


# Check Total Count
print("Amount of listings Scraped: "+str(len(l)))
# List Completed if number > 0 || Empty
        


for i in range(0,len(l)):

    cost.append(l[i]['pricing'])
    beds.append(l[i]['beds'])
    baths.append(l[i]['baths'])
    sqft.append(l[i]['sqft'])
    types.append(l[i]['type'])
    address.append(l[i]['address'])


# Create Price Column
house_df['Price'] = cost

# Create Beds Column
house_df['Beds'] = beds

# Create Baths Column
house_df['Baths'] = baths

# Create Square Feet Column
house_df['Square_Feet'] = sqft

# Create Type Column
house_df['Type'] = types

# Create Address Column
house_df['Address'] = address


# Format Columns as String
house_df['Price'] = house_df['Price'].astype('str')
house_df['Beds'] = house_df['Beds'].astype('str')
house_df['Baths'] = house_df['Baths'].astype('str')
house_df['Square_Feet'] = house_df['Square_Feet'].astype('str')
house_df['Type'] = house_df['Type'].astype('str')
house_df['Address'] = house_df['Address'].astype('str')

house_df.drop_duplicates()

# Print to Check Output
display(house_df)

# %% [markdown]
# #### Export to Excel File

# %%
# Create an export to Excel File for Furthur Analysis

# Create File Name
fileName = 'WV - RealEstateData.xlsx'

# Export to Excel; Sheet Named: 'Real Estate Data';
with pd.ExcelWriter(fileName, engine="openpyxl", mode="w") as writer:
    house_df.to_excel(writer, 'WV - Real Estate Data', index=False)
